# %% [markdown]
# ### Retrieval-Augmented Generation (RAG) - Advanced -  Multi Query Translation
# **Problem:** User queries are challenging. If user provides an ambiguous query, they will get ambiguous matches.
#              LLMs just follow what was in the context and produce the results as it is.
#
# **Solution:** There are multiple ways to tackle the above problem.
#
# ![image.png](attachment:image.png)
#
# - More Abstraction: Refers to generalizing or stepping back to view the question from a higher-level perspective.
#   - Example: Instead of directly asking for a specific answer, you might frame a question like, "What broader concepts should I consider for this problem?"
# - Less Abstraction: Refers to breaking the question into specific, granular sub-questions that are easier to answer..
#   - Example: For the question, "How does climate change affect agriculture?" sub-questions might be:
#     - "What is climate change?"
#     - "What are the main impacts of climate change on crop growth?"
# - Rewriting the query using RAG-Fusion or Multi-Query
#   - **RAG-Fusion**: Combining retrieved documents or information from multiple sources to provide a more comprehensive context.
#   - **Multi-Query**: Generating multiple variations of the question to improve the chances of retrieving relevant information.
#
# This section discusses on Multi-Query Translation in RAG
#
# ##### Key Highlights:
# - **Implement Multi-Query Translation**
#   - The question is broke into multiple questions based on different perspectives. This increases the likelihood of retrieving relevant information from the vector store.
#   - Each question is sent to the retriever and fetches the relevant chunk from the vector store.
#
#     ![image-2.png](attachment:image-2.png)
#     ![image-3.png](attachment:image-3.png)
#
#
# ##### What's Next:

# %% [markdown]
# #### Install required libraries

# %%
# Install required libraries
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: bs4 in ./learn_rag/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.0.2)
# Requirement already satisfied: langchain in ./learn_rag/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.3.13)
# Requirement already satisfied: langchain_community in ./learn_rag/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.3.13)
# Requirement already satisfied: langchain_openai in ./learn_rag/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.2.14)
# Requirement already satisfied: chromadb in ./learn_rag/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.5.23)
# Requirement already satisfied: numpy in ./learn_rag/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: beautifulsoup4 in ./learn_rag/lib/python3.11/site-packages (from bs4->-r requirements.txt (line 2)) (4.12.3)
# Requirement already satisfied: PyYAML>=5.3 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.26 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (0.3.28)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (0.3.4)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (0.2.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (2.10.4)
# Requirement already satisfied: requests<3,>=2 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./learn_rag/lib/python3.11/site-packages (from langchain->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./learn_rag/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 4)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in ./learn_rag/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./learn_rag/lib/python3.11/site-packages (from langchain_community->-r requirements.txt (line 4)) (2.7.0)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in ./learn_rag/lib/python3.11/site-packages (from langchain_openai->-r requirements.txt (line 5)) (1.58.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./learn_rag/lib/python3.11/site-packages (from langchain_openai->-r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: build>=1.0.3 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.115.6)
# Requirement already satisfied: uvicorn>=0.18.3 in ./learn_rag/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (3.7.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (1.29.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: importlib-resources in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (1.68.1)
# Requirement already satisfied: bcrypt>=4.0.1 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (31.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in ./learn_rag/lib/python3.11/site-packages (from chromadb->-r requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./learn_rag/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 3)) (1.18.3)
# Requirement already satisfied: packaging>=19.1 in ./learn_rag/lib/python3.11/site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyproject_hooks in ./learn_rag/lib/python3.11/site-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./learn_rag/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 4)) (3.23.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./learn_rag/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in ./learn_rag/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb->-r requirements.txt (line 6)) (0.41.3)
# Requirement already satisfied: anyio in ./learn_rag/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (4.7.0)
# Requirement already satisfied: certifi in ./learn_rag/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in ./learn_rag/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: idna in ./learn_rag/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in ./learn_rag/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in ./learn_rag/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./learn_rag/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.26->langchain->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./learn_rag/lib/python3.11/site-packages (from langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: coloredlogs in ./learn_rag/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: flatbuffers in ./learn_rag/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (24.12.23)
# Requirement already satisfied: protobuf in ./learn_rag/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (5.29.2)
# Requirement already satisfied: sympy in ./learn_rag/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (1.13.3)
# Requirement already satisfied: distro<2,>=1.7.0 in ./learn_rag/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./learn_rag/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai->-r requirements.txt (line 5)) (0.8.2)
# Requirement already satisfied: sniffio in ./learn_rag/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain_openai->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 6)) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 6)) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 6)) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 6)) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: asgiref~=3.0 in ./learn_rag/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb->-r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in ./learn_rag/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 6)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in ./learn_rag/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./learn_rag/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./learn_rag/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 3)) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./learn_rag/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./learn_rag/lib/python3.11/site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./learn_rag/lib/python3.11/site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./learn_rag/lib/python3.11/site-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: regex>=2022.1.18 in ./learn_rag/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain_openai->-r requirements.txt (line 5)) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./learn_rag/lib/python3.11/site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb->-r requirements.txt (line 6)) (0.27.0)
# Requirement already satisfied: click>=8.0.0 in ./learn_rag/lib/python3.11/site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in ./learn_rag/lib/python3.11/site-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in ./learn_rag/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./learn_rag/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in ./learn_rag/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (1.0.3)
# Requirement already satisfied: websockets>=10.4 in ./learn_rag/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (14.1)
# Requirement already satisfied: soupsieve>1.2 in ./learn_rag/lib/python3.11/site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 2)) (2.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./learn_rag/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./learn_rag/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./learn_rag/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (4.9)
# Requirement already satisfied: filelock in ./learn_rag/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb->-r requirements.txt (line 6)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./learn_rag/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb->-r requirements.txt (line 6)) (2024.12.0)
# Requirement already satisfied: zipp>=3.20 in ./learn_rag/lib/python3.11/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./learn_rag/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.26->langchain->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./learn_rag/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./learn_rag/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in ./learn_rag/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./learn_rag/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./learn_rag/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Import required libraries

# %%
import os # Operating system relevant tasks
from dotenv import load_dotenv
import bs4 # Import Beautiful Soap, a Python Web Scrapping package
from langchain_community.document_loaders import WebBaseLoader # Load documents from website
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma # Import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain import hub # Python library containing pre-defined Prompts, Chains for LLM applications
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.prompts import ChatPromptTemplate
import numpy as np
from langchain.load import dumps, loads
from operator import itemgetter

# %% [markdown]
# #### Environment Setup

# %%
# Load environment variables from .env file
load_dotenv()

# API key provides authentication to access LangChain service 
os.environ['LANGCHAIN_TRACING_V2'] = 'true' # Enables LangChain Tracing V2, a mechanism to enable and monitor the execution of LangChain applications for debugging and optimization
os.environ['LANGCHAIN_ENDPOINT'] = 'https://api.smith.langchain.com' # Configures the LangChain API End Point to use LangChain for tracing
os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY")
# API key to access OpenAI services
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# #### RAG Process

# %% [markdown]
# ##### Load, Split, Index

# %%
## Load Documents
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
blog_docs = loader.load() 

## Split the documents based on tokens
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=300, chunk_overlap=50)
splits = text_splitter.split_documents(blog_docs)

## Calculate the vector embeddings of the splits, store in the vector store and convert the vector store into a retriever object
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings()) # Store the vector embeddings of splits in Chroma DB

## Retrieve the documents that are closing matching with prompt using KNN
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# %% [markdown]
# #### **Prompt - Generate multiple queries**
# Write a Prompt in such a way that the query is converted into multiple queries utilizing the capability of LLM model

# %%
# Multi Query: Different Perspectives
template = """You are an AI language model assistant. Your task is to generate five 
different versions of the given user question to retrieve relevant documents from a vector 
database. By generating multiple perspectives on the user question, your goal is to help
the user overcome some of the limitations of the distance-based similarity search. 
Provide these alternative questions separated by newlines. Original question: {question}"""
prompt_perspectives = ChatPromptTemplate.from_template(template)

generate_queries = (
    prompt_perspectives 
    | ChatOpenAI(temperature=0) 
    | StrOutputParser() 
    | (lambda x: x.split("\n"))
)

generate_queries
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='You are an AI language model assistant. Your task is to generate five \ndifferent versions of the given user question to retrieve relevant documents from a vector \ndatabase. By generating multiple perspectives on the user question, your goal is to help\nthe user overcome some of the limitations of the distance-based similarity search. \nProvide these alternative questions separated by newlines. Original question: {question}'), additional_kwargs={})])
# | ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x128f9a610>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x128fdc510>, root_client=<openai.OpenAI object at 0x128fca190>, root_async_client=<openai.AsyncOpenAI object at 0x128f98050>, temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'))
# | StrOutputParser()
# | RunnableLambda(...)

# %%
def get_unique_union(documents: list[list]):
    """ Unique union of retrieved docs """
    # Flatten list of lists, and convert each Document to string
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    # Get unique documents
    unique_docs = list(set(flattened_docs))
    # Return
    return [loads(doc) for doc in unique_docs]

# Retrieve
question = "What is task decomposition for LLM agents?"
retrieval_chain = generate_queries | retriever.map() | get_unique_union
docs = retrieval_chain.invoke({"question":question})
len(docs)
# Out:
# 3

# %% [markdown]
# This is how trace in LangSmith looks like.
# - Five queries are generated from the LLM as shown in the Figure.
# - Retrieved five documents for each query from the vector store. So, five VectorStore Retrievers are seen.
# - The distinct documents from the total retrieved documents are selected. Only 4 such distinct documents are found after getting the union of unique documents.
#     - The reason is same document is retrieved multiple times for a given query. Same documents are retrieved in all queries. So, the number came out to be just 4.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### LLM, Invokde

# %%
template = """Answer the following question based on this context:

{context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# Define LLM
llm = ChatOpenAI(temperature=0)

final_rag_chain = (
    {"context": retrieval_chain, "question": itemgetter("question")} 
    | prompt
    | llm
    | StrOutputParser()
)

# Invoke LLM
final_rag_chain.invoke({"question":question})
# Out:
# 'Task decomposition for LLM agents involves breaking down large tasks into smaller, manageable subgoals, enabling efficient handling of complex tasks. This process can be facilitated through techniques such as Chain of Thought and Tree of Thoughts, which help the model decompose hard tasks into smaller and simpler steps. Task decomposition can be achieved through simple prompting by LLM, task-specific instructions, or human inputs.'

# %% [markdown]
# **Few Takeaways:**
#
# Why Multi-Query Translation in RAG?
# - Improves Recall: By generating multiple queries, the system retrieves information from different angles, reducing the chance of missing relevant data.
# - Handles Vocabulary Mismatch
# - Diversified Results
# - Robustness to Noise
#
# Challenges with Multi-Query Translation?
# - Computational Overhead: Generating multiple queries and retrieving for each one can be resource-intensive.
# - Redundancy: If the same documents are retrieved across multiple queries, there may be overlapping or redundant information.
# - Merging Complexity: Combining the retrieved results while ensuring relevance and avoiding noise can be tricky.
